# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()

OLLAMA_API_KEY = os.getenv("WEB_SEARCH_API_KEY")

# %%
if not OLLAMA_API_KEY:
    raise ValueError("OLLAMA_API_KEY not found in environment variables.")

url = "https://ollama.com/api/web_search"

headers = {
    "Authorization": f"Bearer {OLLAMA_API_KEY}",
    "Content-Type": "application/json"
}

payload = {
    "query": "What is the capital of Italy?",
    "limit": 1
}

try:
    response = requests.post(url, headers=headers, json=payload)
    response.raise_for_status()  # Raises an HTTPError for bad responses
    print(response.json())
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# {'results': [{'title': 'What is the Capital of Italy?', 'url': 'https://worldpopulationreview.com/countries/italy/capital', 'content': 'What is the Capital of Italy?\n# What is the Capital of Italy?\nThe capital ofItalyisRome, which was founded4/21/753 BC.Romehas been the capital since1871.\nRome is the largest city in Italy and functions as: Houses the Prime Minister.\nRomeis located at41.9028° N, 12.4964° E, at an elevation of43&#x27;ft.\n### Vatican City, Rome, Italy\nItaly Capital\nSource:https://flic.kr/p/qQZsht\n2024 Population\n4,331,974\n2024 Growth Rate\n0.38%\nFounded\n4/21/753 BC\nCapital as of\n1871\nElevation\n43&#x27;\nLargest City\nYes\nRole in Country\nHouses the Prime Minister\n## Rome Shown on a Map'}, {'title': 'What Is the Capital of Italy?', 'url': 'https://www.worldatlas.com/articles/what-is-the-capital-of-italy.html', 'content': "What Is the Capital of Italy?\n\nRome is the largest city in Italy and a popular tourist destination.\n\nRome is the largest and the capital of Italy, as well as the capital of the Lazio region. The city has a population of about 2.9 million and its metropolitan area has population of 4.3 million, making it the fourth most populous city in the European Union (EU). The city is located on the shore of the Tiber River in Lazio administrative region. The Vatican is an independent state located entirely within the city of Rome, and remains the only country within a city. Rome is a global city and a popular tourist destination. In fact, it is the third most visited city in the EU and 14th in the world. Rome is a city rich in history, and can be considered as a center of western civilization and democracy. The city has also biblical and archaeological significance.\n\n## Demographics\n\nThe city of Rome has a population of 2.9 million, while its metropolitan area has a population of 4.3 million. Approximately 91% of the population is Italian, and roughly half of the non-Italian population are immigrants from European countries especially Romania, Poland, Ukraine, and Albania. Non-European immigration is predominantly from the Philippines, China and Bangladesh. Roman Catholicism is the dominant religion in Rome, as well as the rest of Italy. The city has been an important center of Roman Catholicism for centuries and is home to St. Peter's Basilica and the Vatican City. The metropolitan area is home to about 900 churches.\n\n## Climate\n\nRome experiences a Mediterranean climate characterized by dry summers and cool but humid winters. The average temperature during the day is about 20 °C and temperatures cool down to 10 °C at night. January is the coldest month, with temperatures dropping to about 12 °C, while July and August are the warmest, with temperatures reaching about 30 °C. Snowfall is not common, but light snow can be experienced during the winter. However, the city experiences heavy snowfall approximately once every 5 years.\n\n## Economy\n\nAs the capital of Italy, Rome is home to various government institutions including the presidency, legislature, judiciary, and diplomatic representatives. Although the largest city in Italy, Rome is not considered an alpha city, and ranks below Milan in the Globalization and World Cities Research Network ranking. The city accounts for 6.7% of Italy's GDP and experiences a growth rate of 4.4% annually. The city's economy is dominated by the service industry, technological companies, construction and commercial development, research, and tourism. Rome is also home to the head offices of major Italian companies and several multinationals.\n\n## Tourism\n\nRome is a popular tourist attraction. In fact, it is the third most visited city in the European Union, after Paris and London, and receives about 10 million visitors annually. The city is home to several archaeological and historical monuments that detail the history of both Italy and and Europe. Approximately four million tourists visit the Colosseum and the Vatican Museums each year.\n\nS ...

# %%
import json

# Decode and parse
decoded_str = response.content.decode('utf-8')
parsed_data = json.loads(decoded_str)

# %%
parsed_data["results"]
# Out:
# [{'title': 'What is the Capital of Italy?',
#   'url': 'https://worldpopulationreview.com/countries/italy/capital',
#   'content': 'What is the Capital of Italy?\n# What is the Capital of Italy?\nThe capital ofItalyisRome, which was founded4/21/753 BC.Romehas been the capital since1871.\nRome is the largest city in Italy and functions as: Houses the Prime Minister.\nRomeis located at41.9028° N, 12.4964° E, at an elevation of43&#x27;ft.\n### Vatican City, Rome, Italy\nItaly Capital\nSource:https://flic.kr/p/qQZsht\n2024 Population\n4,331,974\n2024 Growth Rate\n0.38%\nFounded\n4/21/753 BC\nCapital as of\n1871\nElevation\n43&#x27;\nLargest City\nYes\nRole in Country\nHouses the Prime Minister\n## Rome Shown on a Map'},
#  {'title': 'What Is the Capital of Italy?',
#   'url': 'https://www.worldatlas.com/articles/what-is-the-capital-of-italy.html',
#   'content': "What Is the Capital of Italy?\n\nRome is the largest city in Italy and a popular tourist destination.\n\nRome is the largest and the capital of Italy, as well as the capital of the Lazio region. The city has a population of about 2.9 million and its metropolitan area has population of 4.3 million, making it the fourth most populous city in the European Union (EU). The city is located on the shore of the Tiber River in Lazio administrative region. The Vatican is an independent state located entirely within the city of Rome, and remains the only country within a city. Rome is a global city and a popular tourist destination. In fact, it is the third most visited city in the EU and 14th in the world. Rome is a city rich in history, and can be considered as a center of western civilization and democracy. The city has also biblical and archaeological significance.\n\n## Demographics\n\nThe city of Rome has a population of 2.9 million, while its metropolitan area has a population of 4.3 million. Approximately 91% of the population is Italian, and roughly half of the non-Italian population are immigrants from European countries especially Romania, Poland, Ukraine, and Albania. Non-European immigration is predominantly from the Philippines, China and Bangladesh. Roman Catholicism is the dominant religion in Rome, as well as the rest of Italy. The city has been an important center of Roman Catholicism for centuries and is home to St. Peter's Basilica and the Vatican City. The metropolitan area is home to about 900 churches.\n\n## Climate\n\nRome experiences a Mediterranean climate characterized by dry summers and cool but humid winters. The average temperature during the day is about 20 °C and temperatures cool down to 10 °C at night. January is the coldest month, with temperatures dropping to about 12 °C, while July and August are the warmest, with temperatures reaching about 30 °C. Snowfall is not common, but light snow can be experienced during the winter. However, the city experiences heavy snowfall approximately once every 5 years.\n\n## Economy\n\nAs the capital of Italy, Rome is home to various government institutions including the presidency, legislature, judiciary, and diplomatic representatives. Although the largest city in Italy, Rome is not considered an alpha city, and ranks below Milan in the Globalization and World Cities Research Network ranking. The city accounts for 6.7% of Italy's GDP and experiences a growth rate of 4.4% annually. The city's economy is dominated by the service industry, technological companies, construction and commercial development, research, and tourism. Rome is also home to the head offices of major Italian companies and several multinationals.\n\n## Tourism\n\nRome is a popular tourist attraction. In fact, it is the third most visited city in the European Union, after Paris and London, and receives about 10 million visitors annually. The city is home to several archaeological and historical monuments that detail the history of both Italy and and Europe. Approximately four million tourists visit the Colosseum and the Vatican Museums each year.\n\nShare\n\nVictor Kiprop July 29 2019 in World Facts\n\n1. What Is the Capital of Italy?\n2. World Facts\n3. Home\n\n### What Is The Capital Of The Australian Capital Territory?\n\n### The Largest Cities In Italy\n\n## More in World Facts\n\n### The Largest Countries In Asia By Area\n\n### Olympic Games History\n\n### Is Australia A Country Or A Continent?\n\n### How Many Countries Are Recognized By The United States?\n\n### Commonwealth Of Independent States\n\n### Is Central America Part Of North America?\n\n### Where Is The Caribbean?\n\n### Landlocked States Of The United States\n\n### The 10 Most Densely Populated Countries In The World\n\n### The 10 Most Populated Countries In The World\n\n### Eastern European Countries\n\n### Countries By Population Density"},
#  {'title': 'Rome Facts | Britannica',
#   'url': 'https://britannica.com/facts/Rome',
#   'content': "Rome Facts | Britannica\n\nRome\n\n# Rome: Facts & Related Content\n\nCite\n\nShare\n\nShare\n\nShare to social media\n\nFacebook X\n\nURL\n\nhttps://www.britannica.com/facts/Rome\n\nWritten and fact-checked by\n\nThe Information Architects of Encyclopaedia Britannica\n\nLast Updated: Feb 25, 2026\n\n## News •\n\nDaniela Petroff, AP's longtime fashion and Vatican reporter, dies at 80• Feb. 25, 2026, 4:32 PM ET (AP) ...(Show more)\n\nWhen in Rome: Budapest pizzeria offers time-travel twist with ancient Rome-inspired pie• Feb. 21, 2026, 7:25 AM ET (AP)\n\nThe travertine quarries that built ancient Rome are carving rock for a new generation of temples• Feb. 19, 2026, 4:03 PM ET (AP)\n\nThe Milan Cortina Olympics officially open with a multi-site ceremony for a spread-out Winter Games• Feb. 6, 2026, 5:59 PM ET (AP)\n\nAn angel resembling Italy's Meloni is painted over after an outcry from church and state• Feb. 4, 2026, 7:54 PM ET (AP)\n\nShow less\n\n---\n\n### Did You Know?\n\n- Rome is the only city in the world that surrounds an entire country: Vatican City is an independent nation-state under papal authority that is located within the city of Rome.\n- Togas are seen as a popular garment worn by the ancient Romans, but their use was restricted to male citizens who had not been born into slavery.\n- Rome has not always been the capital of Italy; prior to the unification of Italy in 1870, the capital city was Florence.\n- In 133 BCE, Rome became the first city in the world to reach a population of one million people.\n\n---\n\n### Photos and Videos\n\nSee All Videos and Images →\n\n---\n\n### Related Topics and References\n\nTopics\n\nVenice Milan Florence Naples Genoa Latina Bologna Verona Trieste Palermo\n\nDig Deeper: More Articles That Discuss This Topic\n\n- government: Rome\n- art market: The rise of Rome\n- art market: Rome as an art centre\n- Hellenistic age: The coming of Rome (225–133)\n- Western painting: Rome and Italy, c. 600–850\n- Western architecture: Origins and development in Rome\n- Italy: The acquisition of Venetia and Rome\n- Italy: The role of Rome\n\n---\n\n### Related Quizzes\n\nWonders of the World Quiz\n\nGuess the City by Its River Quiz\n\nWorld Capitals Quiz\n\n50 Capital Cities at Random Quiz\n\nEuropean Capitals Quiz\n\nWorld Cities\n\n---"}]
