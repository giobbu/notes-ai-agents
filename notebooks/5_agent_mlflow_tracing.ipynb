# %%
#! mlflow server -p 5001

# %%
import mlflow
from openai import OpenAI

PORT = "5001"
EXPERIMENT_NAME = "Ollama"
OLLAMA_API_URL = "http://localhost:11434/v1"

LLM_MODEL = "gpt-oss:20b"
TEMPERATURE = 0.1
MAX_TOKENS = 100

# %%
# Set up MLflow autologging and tracking URI
mlflow.openai.autolog()
mlflow.set_tracking_uri(f"http://localhost:{PORT}")
mlflow.set_experiment(EXPERIMENT_NAME)
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1773936146485, experiment_id='1', last_update_time=1773936685002, lifecycle_stage='active', name='Ollama', tags={}, workspace='default'>

# %%
def set_llm(url):
    try:
        client = OpenAI(
            base_url=url,
            api_key="dummy",
        )
        return client
    except Exception as e:
        print(f"Error initializing OpenAI client: {e}")
        return None

client = set_llm(OLLAMA_API_URL)

# %%
response = client.chat.completions.create(
    model=LLM_MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Why is the sky blue?"},
    ],
    temperature=TEMPERATURE,
    max_tokens=MAX_TOKENS,
)
# Out:
# Trace(trace_id=tr-877b690961b3ff9e228e6641bd7f722f)
